# %%
import yfinance as yf
# collect stock data of Apple from 2024-01-01 to 2025-01-01
data = yf.download("AAPL", start = "2024-01-01", end = "2025-01-01")

data.to_csv(r"C:\Users\anush\Documents\Codes\NewsSentiment\data\raw_stock_data.csv")
# Out:
# C:\Users\anush\AppData\Local\Temp\ipykernel_8536\4190650532.py:3: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download("AAPL", start = "2024-01-01", end = "2025-01-01")
# [*********************100%***********************]  1 of 1 completed
