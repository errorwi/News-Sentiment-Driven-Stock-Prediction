# %%
import yfinance as yf
# collect stock data of Apple from 2024-01-01 to 2025-01-01
data = yf.download("AAPL", start = "2024-01-01", end = "2025-01-01", progress = False, auto_adjust = True)

data.to_csv(r"C:\Users\anush\Documents\Codes\NewsSentiment\data\raw_stock_data.csv", index = True)

# %%
print(data.head())
# Out:
# Price            Close        High         Low        Open    Volume
# Ticker            AAPL        AAPL        AAPL        AAPL      AAPL
# Date
# 2024-01-02  183.903229  186.677036  182.169601  185.399096  82488700
# 2024-01-03  182.526230  184.140985  181.713894  182.496512  58414500
# 2024-01-04  180.208130  181.377083  179.187767  180.445875  71983600
# 2024-01-05  179.484955  181.050175  178.484409  180.287390  62379700
# 2024-01-08  183.823975  183.863609  179.801961  180.386437  59144500

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
from GoogleNews import GoogleNews

googlenews = GoogleNews(lang='en')
googlenews.search("AAPL stock")
results = googlenews.result()

analyzer = SentimentIntensityAnalyzer()

for item in results[:5]:
    headline = item['title']
    score = analyzer.polarity_scores(headline)['compound']
    print(f"{score:.3f} --> {headline}")
# Out:
# -0.296 --> Regulatory Pressure Mounts on Apple’s European Operations
# 0.273 --> Karnataka wants Foxconn to create 50,000 jobs by 2026 at iPhone plant
# 0.000 --> Apple Inc. $AAPL is Tompkins Financial Corp's 6th Largest Position
# -0.128 --> Apple Inc. $AAPL Stock Holdings Lowered by General Partner Inc.
# 0.296 --> Peoples Bank KS Sells 6,833 Shares of Apple Inc. $AAPL

# %%
from GoogleNews import GoogleNews
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
import pandas as pd

googlenews = GoogleNews(lang='en')
googlenews.search("AAPL stock")
results = googlenews.result()

analyzer = SentimentIntensityAnalyzer()

dates = []
sentiments = []

for item in results:
    headline = item['title']
    date = item['date']  
    try:
        date = pd.to_datetime(date)
    except:
        date = pd.Timestamp.today() 
    score = analyzer.polarity_scores(headline)['compound']
    dates.append(date)
    sentiments.append(score)

sentiment_df = pd.DataFrame({"date": dates, "sentiment": sentiments})

print(sentiment_df.head())
# Out:
#                         date  sentiment
# 0 2025-12-23 18:22:20.342025    -0.2960
# 1 2025-12-23 18:22:20.342025     0.2732
# 2 2025-12-23 18:22:20.342025     0.0000
# 3 2025-12-23 18:22:20.342025    -0.1280
# 4 2025-12-23 18:22:20.343025     0.2960
